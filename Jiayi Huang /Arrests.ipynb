# %%
import pandas as pd
import numpy as np
import geopandas
# %matplotlib inline
import matplotlib.pyplot as plt

incidents = pd.read_csv("Arrests.csv")
Neighborhood = incidents['INCIDENTNEIGHBORHOOD']
Incidents = incidents['INCIDENTNEIGHBORHOOD'].value_counts()
Incidents.sort_values()
# Out:
# Mt. Oliver Neighborhood         2
# Troy Hill-Herrs Island          6
# Mt. Oliver Boro                18
# Central Northside              23
# Regent Square                  28
#                              ...
# Homewood South               1747
# East Allegheny               1781
# Carrick                      1966
# South Side Flats             2858
# Central Business District    3327
# Name: INCIDENTNEIGHBORHOOD, Length: 98, dtype: int64

# %%
incidents['INCIDENTNEIGHBORHOOD'].value_counts().tail(15).plot(kind='bar')

# %%
neighborhoods = geopandas.read_file("INCIDENTNEIGHBORHOOD") # read in the shapefile
neighborhoods.plot()
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/_shim.pyx in fiona._shim.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: INCIDENTNEIGHBORHOOD: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-47-ca7e6ae6f88e> in <module>
# ----> 1 neighborhoods = geopandas.read_file("INCIDENTNEIGHBORHOOD") # read in the shapefile
#       2 neighborhoods.plot()
#
# /opt/tljh/user/lib/python3.8/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#      94
#      95     with fiona_env():
# ---> 96         with reader(path_or_bytes, **kwargs) as features:
#      97
#      98             # In a future Fiona release the crs attribute of features will
#
# ...
